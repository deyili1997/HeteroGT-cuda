# %%
from set_seed_utils import set_random_seed
import os
import random
import numpy as np
import pickle
import torch
from tqdm import tqdm
from torch.utils.data import DataLoader
from token_utils_rep import EHRTokenizer
from dataset_utils_rep import HBERTFinetuneEHRDataset, batcher, UniqueIDSampler
from HEART_rep import HBERT_Finetune
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score, auc, precision_recall_curve, precision_recall_fscore_support
import pandas as pd
# Out:
# Disabling PyTorch because PyTorch >= 2.1 is required but found 1.13.1
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
PHENO_ORDER = [
    "Acute and unspecified renal failure",
    "Acute cerebrovascular disease",
    "Acute myocardial infarction",
    "Cardiac dysrhythmias",
    "Chronic kidney disease",
    "Chronic obstructive pulmonary disease",
    "Conduction disorders",
    "Congestive heart failure; nonhypertensive",
    "Coronary atherosclerosis and related",
    "Disorders of lipid metabolism",
    "Essential hypertension",
    "Fluid and electrolyte disorders",
    "Gastrointestinal hemorrhage",
    "Hypertension with complications",
    "Other liver diseases",
    "Other lower respiratory disease",
    "Pneumonia",
    "Septicemia (except in labor)",
]

# %%
@torch.no_grad()
def evaluate(model, dataloader, device, long_seq_idx=None, task_type="binary"):
    model.eval()
    predicted_scores, gt_labels = [], []

    # 推理：收集 logits 与 labels
    for _, batch in enumerate(tqdm(dataloader, desc="Running inference")):
        batch = [x.to(device) if isinstance(x, torch.Tensor) else x for x in batch]
        labels = batch[-1]
        output_logits = model(*batch[:-1])
        predicted_scores.append(output_logits)
        gt_labels.append(labels)

    if task_type == "binary":
        # —— 标准二分类评估 —— #
        logits_all = torch.cat(predicted_scores, dim=0).view(-1)          # logits [N]
        labels_all = torch.cat(gt_labels, dim=0).view(-1).cpu().numpy()    # y_true [N]
        scores_all = logits_all.cpu().numpy()                              # 连续分数（logits）
        ypred_all  = (logits_all > 0).float().cpu().numpy()                # logits > 0

        tp = (ypred_all * labels_all).sum()
        precision = tp / (ypred_all.sum() + 1e-8)
        recall    = tp / (labels_all.sum() + 1e-8)
        f1        = 2 * precision * recall / (precision + recall + 1e-8)
        roc_auc   = roc_auc_score(labels_all, scores_all)
        prec_curve, rec_curve, _ = precision_recall_curve(labels_all, scores_all)
        pr_auc    = auc(rec_curve, prec_curve)

        all_performance = {"precision": float(precision),
                           "recall": float(recall),
                           "f1": float(f1),
                           "auc": float(roc_auc),
                           "prauc": float(pr_auc)}

        subset_performance = None
        if long_seq_idx is not None:
            idx = torch.as_tensor(long_seq_idx, device=logits_all.device, dtype=torch.long)
            logits_sub = logits_all.index_select(0, idx).view(-1)
            labels_sub = torch.as_tensor(labels_all, device=logits_all.device)[idx].cpu().numpy()
            scores_sub = logits_sub.cpu().numpy()
            ypred_sub  = (logits_sub > 0).float().cpu().numpy()

            tp = (ypred_sub * labels_sub).sum()
            precision = tp / (ypred_sub.sum() + 1e-8)
            recall    = tp / (labels_sub.sum() + 1e-8)
            f1        = 2 * precision * recall / (precision + recall + 1e-8)
            roc_auc   = roc_auc_score(labels_sub, scores_sub)
            prec_curve, rec_curve, _ = precision_recall_curve(labels_sub, scores_sub)
            pr_auc    = auc(rec_curve, prec_curve)

            subset_performance = {"precision": float(precision),
                                  "recall": float(recall),
                                  "f1": float(f1),
                                  "auc": float(roc_auc),
                                  "prauc": float(pr_auc)}

        return all_performance, subset_performance

    else:
        # —— Multi-label evaluation（按类聚合） —— #
        logits_all = torch.cat(predicted_scores, dim=0)    # [B, C]
        labels_all_t = torch.cat(gt_labels, dim=0)         # [B, C]

        def _compute_metrics(logits_sub, labels_sub):
            # 连续分数（概率）：sigmoid(logits)，CPU + fp16 先升为 fp32
            if logits_sub.device.type == "cpu" and logits_sub.dtype == torch.float16:
                prob_t = torch.sigmoid(logits_sub.float())
            else:
                prob_t = torch.sigmoid(logits_sub)
            # 二值化：logits > 0
            ypred_t = (logits_sub > 0).to(torch.int32)

            y_true = labels_sub.cpu().numpy().astype(np.int32)       # [N, C]
            y_pred = ypred_t.cpu().numpy().astype(np.int32)          # [N, C]
            scores = prob_t.cpu().numpy()                             # [N, C]

            # per-class P/R/F1
            p_cls, r_cls, f1_cls, _ = precision_recall_fscore_support(
                y_true, y_pred, average=None, zero_division=0
            )

            # per-class AUC / PR-AUC
            C = y_true.shape[1]
            aucs, praucs = [], []
            for c in range(C):
                yt, ys = y_true[:, c], scores[:, c]
                if yt.max() == yt.min():
                    aucs.append(np.nan)
                    praucs.append(np.nan)
                else:
                    aucs.append(roc_auc_score(yt, ys))
                    prec_curve, rec_curve, _ = precision_recall_curve(yt, ys)
                    praucs.append(auc(rec_curve, prec_curve))

            # 宏平均（忽略 NaN）
            summary = {
                "precision": float(np.mean(p_cls)),
                "recall":    float(np.mean(r_cls)),
                "f1":        float(np.mean(f1_cls)),
                "auc":       float(np.nanmean(aucs)) if np.any(~np.isnan(aucs)) else float("nan"),
                "prauc":     float(np.nanmean(praucs)) if np.any(~np.isnan(praucs)) else float("nan"),
            }

            per_class_df = pd.DataFrame({
                "precision": p_cls,
                "recall":    r_cls,
                "f1":        f1_cls,
                "auc":       aucs,
                "prauc":     praucs,
            }, index=PHENO_ORDER)   # 确保 PHENO_ORDER 已定义且长度=C

            return {"global": summary, "per_class": per_class_df}

        # 全量
        all_performance = _compute_metrics(logits_all, labels_all_t)

        # 子集
        subset_performance = None
        if long_seq_idx is not None:
            idx = torch.as_tensor(long_seq_idx, device=logits_all.device, dtype=torch.long)
            subset_performance = _compute_metrics(
                logits_all.index_select(0, idx),
                labels_all_t.index_select(0, idx)
            )

        return all_performance, subset_performance

# %%
args = {
    "seed": 0,
    "dataset": "MIMIC-IV", 
    "task": "next_diag_12m",  # options: death, stay, readmission, next_diag_6m, next_diag_12m
    "encoder": "hi_edge",  # options: hi_edge, hi_node, hi_edge_node
    "batch_size": 4,
    "eval_batch_size": 4,
    "pretrain_mask_rate": 0.7,
    "pretrain_anomaly_rate": 0.05,
    "pretrain_anomaly_loss_weight": 1,
    "pretrain_pos_weight": 1,
    "lr": 1e-4,
    "epochs": 50,
    "num_hidden_layers": 5,
    "num_attention_heads": 6,
    "attention_probs_dropout_prob": 0.2,
    "hidden_dropout_prob": 0.2,
    "edge_hidden_size": 32,
    "hidden_size": 288,  # must be divisible by num_attention_heads
    "intermediate_size": 288,
    "save_model": True,
    "gat": "dotattn",
    "gnn_n_heads": 1,
    "gnn_temp": 1,
    "diag_med_emb": "tree",  # simple, tree
    "early_stop_patience": 5,
}

# %%
exp_name = "Pretrain-HBERT" \
    + "-" + str(args["dataset"]) \
    + "-" + str(args["encoder"]) \
    + "-" + str(args["pretrain_mask_rate"]) \
    + "-" + str(args["pretrain_anomaly_rate"]) \
    + "-" + str(args["pretrain_anomaly_loss_weight"]) \
    + "-" + str(args["hidden_size"]) \
    + "-" + str(args["edge_hidden_size"]) \
    + "-" + str(args["num_hidden_layers"]) \
    + "-" + str(args["num_attention_heads"]) \
    + "-" + str(args["attention_probs_dropout_prob"]) \
    + "-" + str(args["hidden_dropout_prob"]) \
    + "-" + str(args["intermediate_size"]) \
    + "-" + str(args["gat"]) \
    + "-" + str(args["gnn_n_heads"]) \
    + "-" + str(args["gnn_temp"]) \
    + "-" + str(args["diag_med_emb"])
print(exp_name)
# Out:
# Pretrain-HBERT-MIMIC-IV-hi_edge-0.7-0.05-1-288-32-5-6-0.2-0.2-288-dotattn-1-1-tree

# %%
pretrained_weight_path = "./pretrained_models/" + exp_name + f"/pretrained_model.pt"
finetune_exp_name = f"Finetune-{args['task']}-" + exp_name
save_path = "./saved_model/" + finetune_exp_name
if args["save_model"] and not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
args["predicted_token_type"] = ["diag", "med", "pro", "lab"]
args["special_tokens"] = ("[PAD]", "[CLS]", "[SEP]", "[MASK0]", "[MASK1]", "[MASK2]", "[MASK3]")
args["max_visit_size"] = 15

full_data_path = f"/home/lideyi/HeteroGT-cuda/data_process/{args['dataset']}-processed/mimic.pkl"

if args["task"] == "next_diag_6m":
    finetune_data_path = f"/home/lideyi/HeteroGT-cuda/data_process/{args['dataset']}-processed/mimic_nextdiag_6m.pkl"
elif args["task"] == "next_diag_12m":
    finetune_data_path = f"/home/lideyi/HeteroGT-cuda/data_process/{args['dataset']}-processed/mimic_nextdiag_12m.pkl"
else:
    finetune_data_path = f"/home/lideyi/HeteroGT-cuda/data_process/{args['dataset']}-processed/mimic_downstream.pkl"

# %%
ehr_data = pickle.load(open(full_data_path, 'rb'))
diag_sentences = ehr_data["ICD9_CODE"].values.tolist()
med_sentences = ehr_data["NDC"].values.tolist()
lab_sentences = ehr_data["LAB_TEST"].values.tolist()
pro_sentences = ehr_data["PRO_CODE"].values.tolist()
gender_set = [["M"], ["F"]]
age_gender_set = [[str(c) + "_" + gender] for c in set(ehr_data["AGE"].values.tolist()) for gender in ["M", "F"]]
age_set = [[c] for c in set(ehr_data["AGE"].values.tolist())]

# %%
tokenizer = EHRTokenizer(diag_sentences, med_sentences, lab_sentences, 
                         pro_sentences, gender_set, age_set, age_gender_set, special_tokens=args["special_tokens"])
tokenizer.build_tree()

# %%
train_data, val_data, test_data = pickle.load(open(finetune_data_path, 'rb'))

train_dataset = HBERTFinetuneEHRDataset(
    train_data, tokenizer, 
    token_type=args["predicted_token_type"], 
    task=args["task"]
)

val_dataset = HBERTFinetuneEHRDataset(
    val_data, tokenizer, 
    token_type=args["predicted_token_type"], 
    task=args["task"]
)

test_dataset = HBERTFinetuneEHRDataset(
    test_data, tokenizer, 
    token_type=args["predicted_token_type"], 
    task=args["task"]
)

train_dataloader = DataLoader(
    train_dataset, 
    batch_sampler=UniqueIDSampler(train_dataset.get_ids(), batch_size=args["batch_size"]),
    collate_fn=batcher(pad_id=tokenizer.vocab.word2id["[PAD]"], is_train=False), 
)

val_dataloader = DataLoader(
    val_dataset, 
    batch_sampler=UniqueIDSampler(val_dataset.get_ids(), batch_size=args["batch_size"]),
    collate_fn=batcher(pad_id=tokenizer.vocab.word2id["[PAD]"], is_train=False), 
)

test_dataloader = DataLoader(
    test_dataset, 
    batch_sampler=UniqueIDSampler(test_dataset.get_ids(), batch_size=args["eval_batch_size"]),
    collate_fn=batcher(pad_id=tokenizer.vocab.word2id["[PAD]"], is_train=False),
)

# %%
long_adm_seq_crite = 3
val_long_seq_idx, test_long_seq_idx = [], []
for i in range(len(val_dataset)):
    hadm_id = list(val_dataset.records.keys())[i]
    num_adms = len(val_dataset.records[hadm_id])
    if num_adms >= long_adm_seq_crite:
        val_long_seq_idx.append(i)
for i in range(len(test_dataset)):
    hadm_id = list(test_dataset.records.keys())[i]
    num_adms = len(test_dataset.records[hadm_id])
    if num_adms >= long_adm_seq_crite:
        test_long_seq_idx.append(i)
print(len(val_long_seq_idx), len(test_long_seq_idx))
# Out:
# 857 876

# %%
# examine a batch
batch = next(iter(train_dataloader))  # 取第一个 batch
input_ids, input_types, edge_index, visit_positions, labeled_batch_idx, labels = batch

# 打印每个张量的形状
print("input_ids shape:", input_ids.shape)
print("input_types shape:", input_types.shape)
print("visit_positions shape:", visit_positions.shape)
print("labeled_batch_idx shape:", len(labeled_batch_idx)) # it is a list
print("labels shape:", labels.shape)
# Out:
# input_ids shape: torch.Size([9, 64])
# input_types shape: torch.Size([9, 64])
# visit_positions shape: torch.Size([9])
# labeled_batch_idx shape: 4
# labels shape: torch.Size([4, 18])

# %%
args["vocab_size"] = len(args["special_tokens"]) + \
                     len(tokenizer.diag_voc.id2word) + \
                     len(tokenizer.pro_voc.id2word) + \
                     len(tokenizer.med_voc.id2word) + \
                     len(tokenizer.lab_voc.id2word) + \
                     len(tokenizer.age_voc.id2word) + \
                     len(tokenizer.gender_voc.id2word) + \
                     len(tokenizer.age_gender_voc.id2word)
args["label_vocab_size"] = 18  # only for diagnosis

# %%
if args["task"] in ["death", "stay", "readmission"]:
    eval_metric = "f1"
    task_type = "binary"
    loss_fn = F.binary_cross_entropy_with_logits
else:
    eval_metric = "prauc"
    task_type = "l2r"
    loss_fn = lambda x, y: F.binary_cross_entropy_with_logits(x, y)

# %%
def train_with_early_stopping(model, 
                              train_dataloader, 
                              val_dataloader, 
                              test_dataloader,
                              optimizer, 
                              loss_fn, 
                              device, 
                              args,
                              val_long_seq_idx = None,
                              test_long_seq_idx = None,
                              task_type="binary", 
                              eval_metric="f1"):
    best_score = 0.
    best_val_metric = None
    best_test_metric = None
    best_test_long_seq_metric = None
    epochs_no_improve = 0

    for epoch in range(1, 1 + args["epochs"]):
        model.train()
        ave_loss = 0.

        for step, batch in enumerate(tqdm(train_dataloader, desc="Training Batches")):
            batch = [x.to(device) if isinstance(x, torch.Tensor) else x for x in batch]

            labels = batch[-1].float()
            output_logits = model(*batch[:-1])
            
            loss = loss_fn(output_logits.view(-1), labels.view(-1))
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            ave_loss += loss.item()
            

        ave_loss /= (step + 1)

        # Evaluation
        val_metric, val_long_seq_metric = evaluate(model, val_dataloader, device, task_type=task_type, long_seq_idx=val_long_seq_idx)
        test_metric, test_long_seq_metric = evaluate(model, test_dataloader, device, task_type=task_type, long_seq_idx=test_long_seq_idx)

        if task_type != "binary":
            val_per_class_df = val_metric["per_class"]
            val_metric = val_metric["global"]
            test_per_class_df = test_metric["per_class"]
            test_metric = test_metric["global"]
            
            if val_long_seq_idx != None:
                val_long_seq_per_class_df = val_long_seq_metric["per_class"]
                val_long_seq_metric = val_long_seq_metric["global"]
            if test_long_seq_idx != None:
                test_long_seq_per_class_df = test_long_seq_metric["per_class"]
                test_long_seq_metric = test_long_seq_metric["global"]

        # Logging
        print(f"Epoch: {epoch:03d}, Average Loss: {ave_loss:.4f}")
        print(f"Validation: {val_metric}")
        print(f"Test:       {test_metric}")

        # Check for improvement
        current_score = val_metric[eval_metric]
        if current_score > best_score:
            best_score = current_score
            best_val_metric = val_metric if task_type == "binary" else {"global": val_metric, "per_class": val_per_class_df}
            best_test_metric = test_metric if task_type == "binary" else {"global": test_metric, "per_class": test_per_class_df}
            best_test_long_seq_metric = test_long_seq_metric if task_type == "binary" else {"global": test_long_seq_metric, "per_class": test_long_seq_per_class_df}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        # Early stopping check
        if epochs_no_improve >= args["early_stop_patience"]:
            print(f"\nEarly stopping triggered after {epoch} epochs (no improvement for {args['early_stop_patience']} epochs).")
            break

    print("\nBest validation performance:")
    print(best_val_metric)
    print("Corresponding test performance:")
    print(best_test_metric)
    if best_test_long_seq_metric is not None:
        print("Corresponding test-long performance:")
        print(best_test_long_seq_metric)
    return best_test_metric, best_test_long_seq_metric

# %%
random.seed(42)
seeds = [random.randint(0, 2**32 - 1) for _ in range(2)]
print(seeds)
# Out:
# [2746317213, 1181241943]

# %%
final_metrics, final_long_seq_metrics = [], []

for seed in seeds:
    args["seed"] = seed
    set_random_seed(args["seed"])
    print(f"Training with seed: {args['seed']}")
    
    # Initialize model, optimizer, and loss function
    model = HBERT_Finetune(args, tokenizer)
    model.load_weight(torch.load(pretrained_weight_path, weights_only=True))
    model = model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=args["lr"])
    
    best_test_metric, best_test_long_seq_metric = train_with_early_stopping(
        model, 
        train_dataloader, 
        val_dataloader, 
        test_dataloader,
        optimizer, 
        loss_fn, 
        device, 
        args,
        val_long_seq_idx,
        test_long_seq_idx,
        task_type=task_type)
    
    final_metrics.append(best_test_metric)
    final_long_seq_metrics.append(best_test_long_seq_metric)
# Out:
# [INFO] Random seed set to 2746317213
# Training with seed: 2746317213
# Training Batches: 100%|██████████| 1713/1713 [00:53<00:00, 31.79it/s]
# Running inference: 100%|██████████| 1262/1262 [00:10<00:00, 119.15it/s]
# Running inference: 100%|██████████| 1266/1266 [00:10<00:00, 115.69it/s]
# Epoch: 001, Average Loss: 0.3194
# Validation: {'precision': 0.36653050013800115, 'recall': 0.29816453171596613, 'f1': 0.31506636205104777, 'auc': 0.7396859936062491, 'prauc': 0.40539325123665965}
# Test:       {'precision': 0.36285821842767385, 'recall': 0.30205408997960376, 'f1': 0.3164486632588266, 'auc': 0.7411258046130121, 'prauc': 0.4061701551177983}
# Training Batches: 100%|██████████| 1713/1713 [00:53<00:00, 31.98it/s]
# Running inference: 100%|██████████| 1262/1262 [00:10<00:00, 118.86it/s]
# Running inference: 100%|██████████| 1266/1266 [00:11<00:00, 111.00it/s]
# Epoch: 002, Average Loss: 0.2903
# Validation: {'precision': 0.4237791231853325, 'recall': 0.3367245729599685, 'f1': 0.35680573146807365, 'auc': 0.7658821629070451, 'prauc': 0.42818748387171307}
# Test:       {'precision': 0.424181981121111, 'recall': 0.3411517547123728, 'f1': 0.35733147268326554, 'auc': 0.7640416619400885, 'prauc': 0.4275362235649526}
#
# Best validation performance:
# {'global': {'precision': 0.4237791231853325, 'recall': 0.3367245729599685, 'f1': 0.35680573146807365, 'auc': 0.7658821629070451, 'prauc': 0.42818748387171307}, 'per_class':                                            precision    recall        f1  \
# Acute and unspecified renal failure         0.527457  0.315471  0.394808
# Acute cerebrovascular disease               0.000000  0.000000  0.000000
# Acute myocardial infarction                 0.000000  0.000000  0.000000
# Cardiac dysrhythmias                        0.833017  0.641344  0.724721
# Chronic kidney disease                      0.838249  0.757524  0.795845
# Chronic obstructive pulmonary disease       0.659259  0.198661  0.305317
# Conduction disorders                        0.000000  0.000000  0.000000
# Congestive heart failure; nonhypertensive   0.726795  0.733216  0.729991
# Coronary atherosclerosis and related        0.761372  0.838948  0.798280
# Disorders of lipid metabolism               0.752420  0.780655  0.766278
# Essential hypertension                      0.761339  0.823726  0.791304
# Fluid and electrolyte disorders             0.585956  0.149199  0.237838
# Gastrointestinal hemorrhage                 0.000000  0.000000  0.000000
# Hypertension with complications             0.751503  0.746269  0.748877
# Other liver diseases                        0.000000  0.000000  0.000000
# Other lower respiratory disease             0.430657  0.076031  0.129244
# Pneumonia                                   0.000000  0.000000  0.000000
# Septicemia (except in labor)                0.000000  0.000000  0.000000
#
#                                                 auc     prauc
# Acute and unspecified renal failure        0.746552  0.451613
# Acute cerebrovascular disease              0.556398  0.007570
# Acute myocardial infarction                0.760850  0.100318
# Cardiac dysrhythmias                       0.855786  0.768572
# Chronic kidney disease                     0.923215  0.850271
# Chronic obstructive pulmonary disease      0.860006  0.524808
# Conduction disorders                       0.755707  0.049946
# Congestive heart failure; nonhypertensive  0.905555  0.755513
# Coronary atherosclerosis and related       0.927950  0.805876
# Disorders of lipid metabolism              0.872262  0.766553
# Essential hypertension                     0.872747  0.801667
# Fluid and electrolyte disorders            0.660124  0.474655
# Gastrointestinal hemorrhage                0.587682  0.038863
# Hypertension with complications            0.914473  0.775073
# Other liver diseases                       0.641664  0.017775
# Other lower respiratory disease            0.686437  0.293876
# Pneumonia                                  0.638083  0.111921
# Septicemia (except in labor)               0.620387  0.112504  }
# Corresponding test performance:
# {'global': {'precision': 0.424181981121111, 'recall': 0.3411517547123728, 'f1': 0.35733147268326554, 'auc': 0.7640416619400885, 'prauc': 0.4275362235649526}, 'per_class':                                            precision    recall        f1  \
# Acute and unspecified renal failure         0.503420  0.317515  0.389418
# Acute cerebrovascular disease               0.000000  0.000000  0.000000
# Acute myocardial infarction                 0.000000  0.000000  0.000000
# Cardiac dysrhythmias                        0.801811  0.600603  0.686773
# Chronic kidney disease                      0.849611  0.775848  0.811056
# Chronic obstructive pulmonary disease       0.612613  0.159624  0.253259
# Conduction disorders                        0.000000  0.000000  0.000000
# Congestive heart failure; nonhypertensive   0.723577  0.769231  0.745706
# Coronary atherosclerosis and related        0.744023  0.847078  0.792213
# Disorders of lipid metabolism               0.756895  0.807629  0.781439
# Essential hypertension                      0.754218  0.824526  0.787807
# Fluid and electrolyte disorders             0.575243  0.149338  0.237119
# Gastrointestinal hemorrhage                 0.000000  0.000000  0.000000
# Hypertension with complications             0.780533  0.795880  0.788132
# Other liver diseases                        0.000000  0.000000  0.000000
# Other lower respiratory disease             0.533333  0.093458  0.159046
# Pneumonia                                   0.000000  0.000000  0.000000
# Septicemia (except in labor)                0.000000  0.000000  0.000000
#
#                                                 auc     prauc
# Acute and unspecified renal failure        0.739673  0.434584
# Acute cerebrovascular disease              0.528673  0.007781
# Acute myocardial infarction                0.762053  0.097180
# Cardiac dysrhythmias                       0.836963  0.709239
# Chronic kidney disease                     0.923526  0.863311
# Chronic obstructive pulmonary disease      0.852823  0.490522
# Conduction disorders                       0.734782  0.059007
# Congestive heart failure; nonhypertensive  0.906916  0.774234
# Coronary atherosclerosis and related       0.923103  0.782158
# Disorders of lipid metabolism              0.877508  0.758245
# Essential hypertension                     0.871381  0.787555
# Fluid and electrolyte disorders            0.658115  0.463272
# Gastrointestinal hemorrhage                0.616346  0.065857
# Hypertension with complications            0.923409  0.793518
# Other liver diseases                       0.667157  0.034327
# Other lower respiratory disease            0.663409  0.316828
# Pneumonia                                  0.619080  0.120221
# Septicemia (except in labor)               0.647833  0.137815  }
# Corresponding test-long performance:
# {'global': {'precision': 0.4255529167344712, 'recall': 0.3384859771872952, 'f1': 0.35549710131477735, 'auc': 0.7557821682351569, 'prauc': 0.4301928600631505}, 'per_class':                                            precision    recall        f1  \
# Acute and unspecified renal failure         0.531746  0.320574  0.400000
# Acute cerebrovascular disease               0.000000  0.000000  0.000000
# Acute myocardial infarction                 0.000000  0.000000  0.000000
# Cardiac dysrhythmias                        0.769737  0.596939  0.672414
# Chronic kidney disease                      0.861244  0.792952  0.825688
# Chronic obstructive pulmonary disease       0.600000  0.126761  0.209302
# Conduction disorders                        0.000000  0.000000  0.000000
# Congestive heart failure; nonhypertensive   0.690355  0.723404  0.706494
# Coronary atherosclerosis and related        0.775934  0.882075  0.825607
# Disorders of lipid metabolism               0.790274  0.773810  0.781955
# Essential hypertension                      0.789189  0.841499  0.814505
# Fluid and electrolyte disorders             0.555556  0.147059  0.232558
# Gastrointestinal hemorrhage                 0.000000  0.000000  0.000000
# Hypertension with complications             0.795918  0.816754  0.806202
# Other liver diseases                        0.000000  0.000000  0.000000
# Other lower respiratory disease             0.500000  0.070922  0.124224
# Pneumonia                                   0.000000  0.000000  0.000000
# Septicemia (except in labor)                0.000000  0.000000  0.000000
#
#                                                 auc     prauc
# Acute and unspecified renal failure        0.739496  0.438146
# Acute cerebrovascular disease              0.351550  0.004071
# Acute myocardial infarction                0.836950  0.138462
# Cardiac dysrhythmias                       0.825998  0.653538
# Chronic kidney disease                     0.920786  0.850698
# Chronic obstructive pulmonary disease      0.856968  0.458328
# Conduction disorders                       0.815038  0.077153
# Congestive heart failure; nonhypertensive  0.876577  0.706015
# Coronary atherosclerosis and related       0.943339  0.838438
# Disorders of lipid metabolism              0.890498  0.798771
# Essential hypertension                     0.887014  0.806419
# Fluid and electrolyte disorders            0.654880  0.447339
# Gastrointestinal hemorrhage                0.535966  0.046871
# Hypertension with complications            0.931035  0.798294
# Other liver diseases                       0.569515  0.112094
# Other lower respiratory disease            0.674714  0.322938
# Pneumonia                                  0.632941  0.134962
# Septicemia (except in labor)               0.660812  0.110934  }
# [INFO] Random seed set to 1181241943
# Training with seed: 1181241943
# Training Batches: 100%|██████████| 1713/1713 [00:54<00:00, 31.58it/s]
# Running inference: 100%|██████████| 1262/1262 [00:10<00:00, 119.91it/s]
# Running inference: 100%|██████████| 1266/1266 [00:10<00:00, 115.76it/s]
# Epoch: 001, Average Loss: 0.3162
# Validation: {'precision': 0.39728999180540736, 'recall': 0.30859342193010214, 'f1': 0.3251637817656664, 'auc': 0.7573582414454281, 'prauc': 0.4196969215614681}
# Test:       {'precision': 0.3989229300095001, 'recall': 0.3128956311064918, 'f1': 0.3283767900516893, 'auc': 0.7551470570508362, 'prauc': 0.4204804346207328}
# Training Batches: 100%|██████████| 1713/1713 [00:53<00:00, 31.82it/s]
# Running inference: 100%|██████████| 1262/1262 [00:10<00:00, 119.68it/s]
# Running inference: 100%|██████████| 1266/1266 [00:11<00:00, 114.21it/s]
# Epoch: 002, Average Loss: 0.2891
# Validation: {'precision': 0.4220536144212887, 'recall': 0.3629220035500082, 'f1': 0.3818250128306875, 'auc': 0.769161303021585, 'prauc': 0.4313512150764148}
# Test:       {'precision': 0.4225371727309469, 'recall': 0.3673799094594739, 'f1': 0.38357827677761996, 'auc': 0.7747405852425553, 'prauc': 0.43311682284128106}
#
# Best validation performance:
# {'global': {'precision': 0.4220536144212887, 'recall': 0.3629220035500082, 'f1': 0.3818250128306875, 'auc': 0.769161303021585, 'prauc': 0.4313512150764148}, 'per_class':                                            precision    recall        f1  \
# Acute and unspecified renal failure         0.523745  0.333621  0.407603
# Acute cerebrovascular disease               0.000000  0.000000  0.000000
# Acute myocardial infarction                 0.000000  0.000000  0.000000
# Cardiac dysrhythmias                        0.835052  0.650840  0.731527
# Chronic kidney disease                      0.847490  0.754944  0.798545
# Chronic obstructive pulmonary disease       0.635965  0.647321  0.641593
# Conduction disorders                        0.000000  0.000000  0.000000
# Congestive heart failure; nonhypertensive   0.764034  0.709364  0.735685
# Coronary atherosclerosis and related        0.783048  0.827445  0.804634
# Disorders of lipid metabolism               0.776549  0.742072  0.758919
# Essential hypertension                      0.763724  0.828490  0.794790
# Fluid and electrolyte disorders             0.507317  0.256473  0.340704
# Gastrointestinal hemorrhage                 0.000000  0.000000  0.000000
# Hypertension with complications             0.771552  0.712438  0.740817
# Other liver diseases                        0.000000  0.000000  0.000000
# Other lower respiratory disease             0.388489  0.069588  0.118033
# Pneumonia                                   0.000000  0.000000  0.000000
# Septicemia (except in labor)                0.000000  0.000000  0.000000
#
#                                                 auc     prauc
# Acute and unspecified renal failure        0.747096  0.452430
# Acute cerebrovascular disease              0.627956  0.012139
# Acute myocardial infarction                0.779726  0.136811
# Cardiac dysrhythmias                       0.865732  0.780909
# Chronic kidney disease                     0.924976  0.849512
# Chronic obstructive pulmonary disease      0.878052  0.546205
# Conduction disorders                       0.706690  0.047646
# Congestive heart failure; nonhypertensive  0.906352  0.773438
# Coronary atherosclerosis and related       0.928592  0.806332
# Disorders of lipid metabolism              0.869757  0.761083
# Essential hypertension                     0.871088  0.796750
# Fluid and electrolyte disorders            0.656668  0.455960
# Gastrointestinal hemorrhage                0.591920  0.042366
# Hypertension with complications            0.919947  0.777693
# Other liver diseases                       0.640641  0.023282
# Other lower respiratory disease            0.676203  0.274971
# Pneumonia                                  0.630432  0.107865
# Septicemia (except in labor)               0.623076  0.118929  }
# Corresponding test performance:
# {'global': {'precision': 0.4225371727309469, 'recall': 0.3673799094594739, 'f1': 0.38357827677761996, 'auc': 0.7747405852425553, 'prauc': 0.43311682284128106}, 'per_class':                                            precision    recall        f1  \
# Acute and unspecified renal failure         0.479896  0.319241  0.383420
# Acute cerebrovascular disease               0.000000  0.000000  0.000000
# Acute myocardial infarction                 0.000000  0.000000  0.000000
# Cardiac dysrhythmias                        0.790972  0.607385  0.687127
# Chronic kidney disease                      0.867673  0.771113  0.816548
# Chronic obstructive pulmonary disease       0.615561  0.631455  0.623407
# Conduction disorders                        0.000000  0.000000  0.000000
# Congestive heart failure; nonhypertensive   0.772321  0.747623  0.759772
# Coronary atherosclerosis and related        0.767083  0.835869  0.800000
# Disorders of lipid metabolism               0.773751  0.767847  0.770788
# Essential hypertension                      0.759725  0.827517  0.792174
# Fluid and electrolyte disorders             0.487356  0.267171  0.345136
# Gastrointestinal hemorrhage                 0.000000  0.000000  0.000000
# Hypertension with complications             0.807460  0.750000  0.777670
# Other liver diseases                        0.000000  0.000000  0.000000
# Other lower respiratory disease             0.483871  0.087617  0.148368
# Pneumonia                                   0.000000  0.000000  0.000000
# Septicemia (except in labor)                0.000000  0.000000  0.000000
#
#                                                 auc     prauc
# Acute and unspecified renal failure        0.748380  0.441492
# Acute cerebrovascular disease              0.574725  0.008974
# Acute myocardial infarction                0.781513  0.108473
# Cardiac dysrhythmias                       0.846374  0.726989
# Chronic kidney disease                     0.931688  0.874927
# Chronic obstructive pulmonary disease      0.872090  0.524056
# Conduction disorders                       0.761261  0.090491
# Congestive heart failure; nonhypertensive  0.910618  0.780423
# Coronary atherosclerosis and related       0.927835  0.800096
# Disorders of lipid metabolism              0.876748  0.752096
# Essential hypertension                     0.873181  0.790115
# Fluid and electrolyte disorders            0.663963  0.448806
# Gastrointestinal hemorrhage                0.612462  0.053582
# Hypertension with complications            0.932411  0.807056
# Other liver diseases                       0.687758  0.017183
# Other lower respiratory disease            0.668183  0.313903
# Pneumonia                                  0.616229  0.112789
# Septicemia (except in labor)               0.659913  0.144654  }
# Corresponding test-long performance:
# {'global': {'precision': 0.4135803751231347, 'recall': 0.359736915560992, 'f1': 0.3753483402408976, 'auc': 0.7553844300040037, 'prauc': 0.42481818017759393}, 'per_class':                                            precision    recall        f1  \
# Acute and unspecified renal failure         0.446970  0.308901  0.365325
# Acute cerebrovascular disease               0.000000  0.000000  0.000000
# Acute myocardial infarction                 0.000000  0.000000  0.000000
# Cardiac dysrhythmias                        0.789474  0.576923  0.666667
# Chronic kidney disease                      0.852217  0.758772  0.802784
# Chronic obstructive pulmonary disease       0.597403  0.621622  0.609272
# Conduction disorders                        0.000000  0.000000  0.000000
# Congestive heart failure; nonhypertensive   0.780488  0.747664  0.763723
# Coronary atherosclerosis and related        0.757085  0.809524  0.782427
# Disorders of lipid metabolism               0.773256  0.791667  0.782353
# Essential hypertension                      0.774026  0.811989  0.792553
# Fluid and electrolyte disorders             0.379085  0.223938  0.281553
# Gastrointestinal hemorrhage                 0.000000  0.000000  0.000000
# Hypertension with complications             0.794444  0.740933  0.766756
# Other liver diseases                        0.000000  0.000000  0.000000
# Other lower respiratory disease             0.500000  0.083333  0.142857
# Pneumonia                                   0.000000  0.000000  0.000000
# Septicemia (except in labor)                0.000000  0.000000  0.000000
#
#                                                 auc     prauc
# Acute and unspecified renal failure        0.745810  0.422341
# Acute cerebrovascular disease              0.513392  0.010077
# Acute myocardial infarction                0.724604  0.088071
# Cardiac dysrhythmias                       0.837407  0.710684
# Chronic kidney disease                     0.921256  0.851130
# Chronic obstructive pulmonary disease      0.864899  0.500208
# Conduction disorders                       0.781987  0.110226
# Congestive heart failure; nonhypertensive  0.904262  0.778389
# Coronary atherosclerosis and related       0.910796  0.787122
# Disorders of lipid metabolism              0.876372  0.763199
# Essential hypertension                     0.866490  0.795026
# Fluid and electrolyte disorders            0.621578  0.389661
# Gastrointestinal hemorrhage                0.558664  0.047617
# Hypertension with complications            0.930731  0.812063
# Other liver diseases                       0.673681  0.015835
# Other lower respiratory disease            0.669026  0.337728
# Pneumonia                                  0.571296  0.082331
# Septicemia (except in labor)               0.624670  0.145019  }

# %%
def topk_avg_performance_formatted(performances, long_seq_performances, k=5):
    metrics = ["f1", "auc", "prauc"]
    scores = {m: np.array([p[m] for p in performances]) for m in metrics}

    # 计算排名（值越大排名越靠前）
    ranks = {m: (-scores[m]).argsort().argsort() + 1 for m in metrics}
    avg_ranks = np.mean(np.stack([ranks[m] for m in metrics], axis=1), axis=1)

    # 选 top-k
    topk_idx = np.argsort(avg_ranks)[:k]
    final_avg = {m: np.mean([performances[i][m] for i in topk_idx]) for m in performances[0].keys()}
    final_std = {m: np.std([performances[i][m] for i in topk_idx], ddof=0) for m in performances[0].keys()}
    final_long_seq_avg = {m: np.mean([long_seq_performances[i][m] for i in topk_idx]) for m in long_seq_performances[0].keys()}
    final_long_seq_std = {m: np.std([long_seq_performances[i][m] for i in topk_idx], ddof=0) for m in long_seq_performances[0].keys()}

    # 打印结果（转百分比，均保留两位小数）
    print("Final Metrics:")
    for m in performances[0].keys():
        mean_val = final_avg[m] * 100
        std_val = final_std[m] * 100
        print(f"{m}: {mean_val:.2f} ± {std_val:.2f}")
    print("\nFinal Long Sequence Metrics:")
    for m in long_seq_performances[0].keys():
        mean_val = final_long_seq_avg[m] * 100
        std_val = final_long_seq_std[m] * 100
        print(f"{m}: {mean_val:.2f} ± {std_val:.2f}")

# %%
def print_per_class_performance(dfs, col_name="prauc"):
    """
    输入一个 DataFrame 列表，对每个疾病在所有表格的指定列计算 mean ± std 并打印。

    参数:
        dfs (list[pd.DataFrame]): 多个表格组成的列表
        col_name (str): 要计算的指标列名 (默认: "prauc")
    """
    # 拼接所有表格
    all_values = pd.concat(dfs, axis=0)

    # 按疾病分组，计算 mean 和 std
    grouped = all_values.groupby(all_values.index)[col_name].agg(["mean", "std"])

    # 打印
    for disease, row in grouped.iterrows():
        mean_val = row["mean"] * 100
        std_val = row["std"] * 100
        print(f"{disease}: {mean_val:.2f} ± {std_val:.2f}")

# %%
if task_type == "binary":
    topk_avg_performance_formatted(final_metrics, final_long_seq_metrics)
else:
    final_metrics_global = [metrics["global"] for metrics in final_metrics]
    final_metrics_per_class = [metrics["per_class"] for metrics in final_metrics]
    final_long_seq_metrics_global = [metrics["global"] for metrics in final_long_seq_metrics]
    final_long_seq_metrics_per_class = [metrics["per_class"] for metrics in final_long_seq_metrics]
    topk_avg_performance_formatted(final_metrics_global, final_long_seq_metrics_global)
    print("\nPer-class performance, all patients:")
    print_per_class_performance(final_metrics_per_class, col_name="prauc")
    print("\nPer-class performance, long seq:")
    print_per_class_performance(final_long_seq_metrics_per_class, col_name="prauc")
# Out:
# Final Metrics:
# precision: 0.42 ± 0.00
# recall: 0.35 ± 0.01
# f1: 0.37 ± 0.01
# auc: 0.77 ± 0.01
# prauc: 0.43 ± 0.00
#
# Final Long Sequence Metrics:
# precision: 41.96 ± 0.60
# recall: 34.91 ± 1.06
# f1: 36.54 ± 0.99
# auc: 75.56 ± 0.02
# prauc: 42.75 ± 0.27
#
# Per-class performance, all patients:
# Acute and unspecified renal failure: 43.80 ± 0.49
# Acute cerebrovascular disease: 0.84 ± 0.08
# Acute myocardial infarction: 10.28 ± 0.80
# Cardiac dysrhythmias: 71.81 ± 1.26
# Chronic kidney disease: 86.91 ± 0.82
# Chronic obstructive pulmonary disease: 50.73 ± 2.37
# Conduction disorders: 7.47 ± 2.23
# Congestive heart failure; nonhypertensive: 77.73 ± 0.44
# Coronary atherosclerosis and related: 79.11 ± 1.27
# Disorders of lipid metabolism: 75.52 ± 0.43
# Essential hypertension: 78.88 ± 0.18
# Fluid and electrolyte disorders: 45.60 ± 1.02
# Gastrointestinal hemorrhage: 5.97 ± 0.87
# Hypertension with complications: 80.03 ± 0.96
# Other liver diseases: 2.58 ± 1.21
# Other lower respiratory disease: 31.54 ± 0.21
# Pneumonia: 11.65 ± 0.53
# Septicemia (except in labor): 14.12 ± 0.48
#
# Per-class performance, long seq:
# Acute and unspecified renal failure: 43.02 ± 1.12
# Acute cerebrovascular disease: 0.71 ± 0.42
# Acute myocardial infarction: 11.33 ± 3.56
# Cardiac dysrhythmias: 68.21 ± 4.04
# Chronic kidney disease: 85.09 ± 0.03
# Chronic obstructive pulmonary disease: 47.93 ± 2.96
# Conduction disorders: 9.37 ± 2.34
# Congestive heart failure; nonhypertensive: 74.22 ± 5.12
# Coronary atherosclerosis and related: 81.28 ± 3.63
# Disorders of lipid metabolism: 78.10 ± 2.52
# Essential hypertension: 80.07 ± 0.81
# Fluid and electrolyte disorders: 41.85 ± 4.08
# Gastrointestinal hemorrhage: 4.72 ± 0.05
# Hypertension with complications: 80.52 ± 0.97
# Other liver diseases: 6.40 ± 6.81
# Other lower respiratory disease: 33.03 ± 1.05
# Pneumonia: 10.86 ± 3.72
# Septicemia (except in labor): 12.80 ± 2.41

# %%
import torch
import pickle
import numpy as np
import pandas as pd
from argparse import Namespace
from torch.utils.data import DataLoader
import torch.nn.functional as F
from heterogt.utils.tokenizer import EHRTokenizer
from heterogt.utils.dataset import FineTuneEHRDataset, batcher, expand_level3
from heterogt.utils.train import train_with_early_stopping, PHENO_ORDER
from heterogt.utils.seed import set_random_seed
from heterogt.model.model import HeteroGTFineTune
# Out:
# Disabling PyTorch because PyTorch >= 2.1 is required but found 1.13.1
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
set_random_seed(123)
# Out:
# [INFO] Random seed set to 123

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
config = Namespace(
    dataset = "MIMIC-III",
    tasks = ["death", "readmission", "stay", "next_diag_6m", "next_diag_12m"],
    task_index = 0,  # index of the task to train
    token_type = ["diag", "med", "lab", "pro"],
    special_tokens = ["[PAD]", "[CLS]"],
    # only for tf layer
    attn_mask_dicts = [{1:[6,7], 2:[6,7], 3:[6,7], 4:[6,7], 5:[6,7], 6:[1,2,3,4,5,6,7], 7:[1,2,3,4,5,6,7]}, 
                       {1:[6,7], 2:[6,7], 3:[6,7], 4:[6,7], 5:[6,7], 6:[1,2,3,4,5,6,7], 7:[1,2,3,4,5,6,7]}], 
    d_model = 64,
    num_heads = 4,
    batch_size = 32,
    lr = 1e-3,
    epochs = 500,
    early_stop_patience = 5,
    group_code_thre = 5,  # if there are group_code_thre diag codes belongs to the same group ICD code, then the group code is generated
    use_pretrained_model = True,
    pretrain_mask_rate = 0.7,
    pretrain_cls_ontology_weight = 5e-2,
    pretrain_visit_ontology_weight = 5e-2,
    pretrain_adm_type_weight = 0,
    dec_loss_lambda = 1e-2,
)

# %%
full_data_path = f"./data_process/{config.dataset}-processed/mimic.pkl"  # for tokenizer
curr_task = config.tasks[config.task_index]
print("Current task:", curr_task)
if curr_task == "next_diag_6m":
    finetune_data_path = f"./data_process/{config.dataset}-processed/mimic_nextdiag_6m.pkl"
elif curr_task == "next_diag_12m":
    finetune_data_path = f"./data_process/{config.dataset}-processed/mimic_nextdiag_12m.pkl"
else:
    finetune_data_path = f"./data_process/{config.dataset}-processed/mimic_downstream.pkl"
# Out:
# Current task: death

# %%
ehr_full_data = pickle.load(open(full_data_path, 'rb'))
group_code_sentences = [expand_level3()[1]]
diag_sentences = ehr_full_data["ICD9_CODE"].values.tolist()
med_sentences = ehr_full_data["NDC"].values.tolist()
lab_sentences = ehr_full_data["LAB_TEST"].values.tolist()
pro_sentences = ehr_full_data["PRO_CODE"].values.tolist()
age_sentences = [[str(c)] for c in set(ehr_full_data["AGE"].values.tolist())] # important of [[]]
adm_type_sentences = ehr_full_data["ADMISSION_TYPE"].values.tolist()
max_admissions = ehr_full_data.groupby("SUBJECT_ID")["HADM_ID"].nunique().max()
config.max_num_adms = max_admissions
print(f"Max admissions per patient: {config.max_num_adms}")
# Out:
# Max admissions per patient: 8

# %%
tokenizer = EHRTokenizer(age_sentences, group_code_sentences, diag_sentences, med_sentences, lab_sentences, 
                         pro_sentences, special_tokens=config.special_tokens, adm_types_sentences=adm_type_sentences)
config.label_vocab_size = len(PHENO_ORDER)  # a set of predifined diseases
config.global_vocab_size = len(tokenizer.vocab.id2word)
config.age_vocab_size = tokenizer.token_number("age")
config.group_code_vocab_size = tokenizer.token_number("group")
print(f"Age vocabulary size: {config.age_vocab_size}")
print(f"Group code vocabulary size: {config.group_code_vocab_size}")
# Out:
# Age vocabulary size: 18
# Group code vocabulary size: 19

# %%
train_data, val_data, test_data = pickle.load(open(finetune_data_path, 'rb'))
# example label percentage
print("Percentage of DEATH in test dataset:",
      (test_data["DEATH"] == True).mean() * 100, "%")

print("Percentage of READMISSION in test dataset:",
      (test_data["READMISSION"] == 1).mean() * 100, "%")

print("Percentage of STAY>7 days in test dataset:",
      (test_data["STAY_DAYS"] > 7).mean() * 100, "%")
# Out:
# Percentage of DEATH in test dataset: 27.5243787354514 %
# Percentage of READMISSION in test dataset: 40.578798364265495 %
# Percentage of STAY>7 days in test dataset: 50.550487574709024 %

# %%
train_dataset = FineTuneEHRDataset(train_data, tokenizer, token_type=config.token_type, task=curr_task, 
                                   max_num_adms=config.max_num_adms, group_code_thre=config.group_code_thre)
val_dataset = FineTuneEHRDataset(val_data, tokenizer, token_type=config.token_type, task=curr_task, 
                                 max_num_adms=config.max_num_adms, group_code_thre=config.group_code_thre)
test_dataset = FineTuneEHRDataset(test_data, tokenizer, token_type=config.token_type, task=curr_task, 
                                   max_num_adms=config.max_num_adms, group_code_thre=config.group_code_thre)

# %%
long_adm_seq_crite = 3
val_long_seq_idx, test_long_seq_idx = [], []
for i in range(len(val_dataset)):
    hadm_id = list(val_dataset.records.keys())[i]
    num_adms = len(val_dataset.records[hadm_id])
    if num_adms >= long_adm_seq_crite:
        val_long_seq_idx.append(i)
for i in range(len(test_dataset)):
    hadm_id = list(test_dataset.records.keys())[i]
    num_adms = len(test_dataset.records[hadm_id])
    if num_adms >= long_adm_seq_crite:
        test_long_seq_idx.append(i)
print(len(val_long_seq_idx), len(test_long_seq_idx))
# Out:
# 777 861

# %%
num_group_code = []
for i in range(len(train_dataset)):
    input_ids, token_types, adm_index, age_ids, diag_group_codes, labels = train_dataset[i]
    count = (token_types[0] == 6).sum().item()
    num_group_code.append(count)
print("Mean group token numer per patient", np.mean(num_group_code))
# Out:
# Mean group token numer per patient 0.820488423723438

# %%
train_dataloader = DataLoader(
    train_dataset,
    collate_fn=batcher(tokenizer, n_token_type=len(config.token_type), is_pretrain = False),
    shuffle=True,
    batch_size=config.batch_size,
)

val_dataloader = DataLoader(
    val_dataset,
    collate_fn=batcher(tokenizer, n_token_type=len(config.token_type), is_pretrain = False),
    shuffle=False,
    batch_size=config.batch_size,
)

test_dataloader = DataLoader(
    test_dataset,
    collate_fn=batcher(tokenizer, n_token_type=len(config.token_type), is_pretrain = False),
    shuffle=False,
    batch_size=config.batch_size,
)

# %%
for batch in train_dataloader:
    pass  # just to check if the dataloader works
for batch in val_dataloader:
    pass  # just to check if the dataloader works
for batch in test_dataloader:
    pass  # just to check if the dataloader works
print("All pass!")
# Out:
# All pass!

# %%
if curr_task in ["death", "stay", "readmission"]:
    eval_metric = "f1"
    task_type = "binary"
    loss_fn = F.binary_cross_entropy_with_logits
else:
    eval_metric = "f1"
    task_type = "l2r"
    loss_fn = lambda x, y: F.binary_cross_entropy_with_logits(x, y)

# %%
input_ids, token_types, adm_index, age_ids, diag_code_group_dicts, labels = next(iter(train_dataloader))
print("Input IDs shape:", input_ids.shape)
print("Token Types shape:", token_types.shape)
print("Admission Index shape:", adm_index.shape)
print("Age IDs shape:", age_ids.shape)
print("Diag Code Group Dict number:", len(diag_code_group_dicts))
print("Labels shape:", labels.shape)
# Out:
# Input IDs shape: torch.Size([32, 178])
# Token Types shape: torch.Size([32, 178])
# Admission Index shape: torch.Size([32, 178])
# Age IDs shape: torch.Size([32, 4])
# Diag Code Group Dict number: 32
# Labels shape: torch.Size([32, 1])

# %% [markdown]
# # Model Walkthrough

# %%
# load pretrained model
if config.use_pretrained_model:
    pretrain_exp_name = (
    f"{config.dataset}-{config.pretrain_mask_rate}-{config.d_model}-{config.pretrain_cls_ontology_weight}-{config.pretrain_visit_ontology_weight}-{config.pretrain_adm_type_weight}"
)
    print(pretrain_exp_name)
    save_path = "./pretrained_models/" + pretrain_exp_name
    state_dict = torch.load(f"{save_path}/pretrained_model.pt", map_location="cpu")
# Out:
# MIMIC-III-0.7-64-0.05-0.05-0

# %%
final_metrics, final_long_seq_metrics, model_weights = [], [], []
for i in range(30):
    print(f"================================{i+1}==================================")
    model = HeteroGTFineTune(tokenizer=tokenizer, token_types=config.token_type, d_model=config.d_model, num_heads=config.num_heads, layer_types=['gnn', 'tf', 'gnn', 'tf'], max_num_adms=config.max_num_adms, 
                     device=device, task=curr_task, label_vocab_size=config.label_vocab_size, attn_mask_dicts=config.attn_mask_dicts,
                     use_cls_cat=True).to(device)
    if config.use_pretrained_model:
        model.load_weight(state_dict)
    optimizer = torch.optim.AdamW(model.parameters(), lr=config.lr)
    best_test_metric, best_test_long_seq_metric, best_model = train_with_early_stopping(model, train_dataloader, val_dataloader, test_dataloader,
                                                                            optimizer, loss_fn, device, config.early_stop_patience, task_type, config.epochs, 
                                                                            dec_loss_lambda=config.dec_loss_lambda, 
                                                                            val_long_seq_idx=val_long_seq_idx, test_long_seq_idx=test_long_seq_idx, 
                                                                            eval_metric=eval_metric, return_model=True)
    final_metrics.append(best_test_metric)
    final_long_seq_metrics.append(best_test_long_seq_metric)
    model_weights.append(best_model)
# Out:
# ================================1==================================
# Epoch 001: 100%|██████████| 99/99 [00:06<00:00, 14.44it/s, loss=0.4385]
# Running inference: 100%|██████████| 196/196 [00:09<00:00, 20.14it/s]
# Running inference: 100%|██████████| 199/199 [00:09<00:00, 20.86it/s]
# Validation: {'precision': 68.6624, 'recall': 73.4988, 'f1': 70.9983, 'auc': 89.3492, 'prauc': 77.6245}
# Test:      {'precision': 68.0548, 'recall': 70.9714, 'f1': 69.4825, 'auc': 88.3463, 'prauc': 75.2018}
#
# Validation-long: {'precision': 38.8889, 'recall': 12.6126, 'f1': 19.0476, 'auc': 72.0538, 'prauc': 29.2264}
# Test-long: {'precision': 40.0, 'recall': 10.1449, 'f1': 16.185, 'auc': 67.8283, 'prauc': 27.4395}
# Epoch 002: 100%|██████████| 99/99 [00:06<00:00, 15.10it/s, loss=0.3600]
# Running inference: 100%|██████████| 196/196 [00:09<00:00, 21.14it/s]
# Running inference: 100%|██████████| 199/199 [00:09<00:00, 21.18it/s]
# Validation: {'precision': 74.0243, 'recall': 66.8014, 'f1': 70.2276, 'auc': 89.7772, 'prauc': 79.9265}
# Test:      {'precision': 73.5406, 'recall': 66.2286, 'f1': 69.6933, 'auc': 89.5518, 'prauc': 78.4575}
#
# Validation-long: {'precision': 31.9588, 'recall': 27.9279, 'f1': 29.8077, 'auc': 73.9848, 'prauc': 30.7598}
# Test-long: {'precision': 40.8163, 'recall': 28.9855, 'f1': 33.8983, 'auc': 71.3818, 'prauc': 32.847}
# Epoch 003: 100%|██████████| 99/99 [00:06<00:00, 15.16it/s, loss=0.3328]
# Running inference: 100%|██████████| 196/196 [00:09<00:00, 20.43it/s]
# Running inference: 100%|██████████| 199/199 [00:09<00:00, 21.20it/s]
# Validation: {'precision': 84.0066, 'recall': 58.8337, 'f1': 69.202, 'auc': 91.2122, 'prauc': 82.3272}
# Test:      {'precision': 82.7922, 'recall': 58.2857, 'f1': 68.4105, 'auc': 90.5669, 'prauc': 80.8458}
#
# Validation-long: {'precision': 50.0, 'recall': 1.8018, 'f1': 3.4783, 'auc': 74.722, 'prauc': 33.435}
# Test-long: {'precision': 87.5, 'recall': 5.0725, 'f1': 9.589, 'auc': 72.1415, 'prauc': 32.1061}
# Epoch 004: 100%|██████████| 99/99 [00:06<00:00, 14.84it/s, loss=0.2808]
# Running inference: 100%|██████████| 196/196 [00:09<00:00, 21.54it/s]
# Running inference: 100%|██████████| 199/199 [00:09<00:00, 21.82it/s]
# Validation: {'precision': 71.5625, 'recall': 79.3303, 'f1': 75.2464, 'auc': 92.283, 'prauc': 83.9057}
# Test:      {'precision': 71.0608, 'recall': 78.8571, 'f1': 74.7562, 'auc': 91.8282, 'prauc': 82.5138}
#
# Validation-long: {'precision': 30.9859, 'recall': 39.6396, 'f1': 34.7826, 'auc': 74.8316, 'prauc': 34.6339}
# Test-long: {'precision': 38.5714, 'recall': 39.1304, 'f1': 38.8489, 'auc': 73.0777, 'prauc': 33.6127}
# Epoch 005:  69%|██████▊   | 68/99 [00:04<00:02, 15.02it/s, loss=0.2467]

# %%
from scipy.stats import rankdata
def get_top_k_model_weights(final_metrics, model_weights, k):
    """
    根据F1、AUC、PRAUC三个指标的平均排名获取Top K实验的模型权重
    
    Args:
        final_metrics: list of dict, 每个字典包含 'f1', 'auc', 'prauc' 键
        model_weights: list, final_metrics
        k: int, 返回前k个最佳实验
    
    Returns:
        list: 前k个实验的模型权重列表
    """
    
    if len(final_metrics) != len(model_weights):
        raise ValueError("final_metrics 和 model_weights 长度必须相等")
    
    if k > len(final_metrics):
        raise ValueError(f"k ({k}) 不能大于实验总数 ({len(final_metrics)})")
    
    # 提取各个指标的值
    f1_scores = [metric['f1'] for metric in final_metrics]
    auc_scores = [metric['auc'] for metric in final_metrics]
    prauc_scores = [metric['prauc'] for metric in final_metrics]
    
    # 计算排名（使用负值让高分数排名靠前）
    f1_ranks = rankdata([-score for score in f1_scores], method='min')
    auc_ranks = rankdata([-score for score in auc_scores], method='min') 
    prauc_ranks = rankdata([-score for score in prauc_scores], method='min')
    
    # 计算平均排名
    avg_ranks = (f1_ranks + auc_ranks + prauc_ranks) / 3
    
    # 获取排名最前的k个索引
    top_k_indices = np.argsort(avg_ranks)[:k]
    
    # 返回对应的模型权重
    return [model_weights[i] for i in top_k_indices]

# %%
top_model_weights = get_top_k_model_weights(final_metrics, model_weights, k = 5)

# %% [markdown]
# # Save Model

# %%
import os
import torch

def save_best_models(best_models, config_dataset, curr_task):
    """
    best_models: list of nn.Module
    """
    # 构建保存路径
    save_dir = os.path.join("parameters", config_dataset, curr_task)
    os.makedirs(save_dir, exist_ok=True)  # 如果文件夹不存在则自动创建

    # 逐个保存模型参数
    for i, model in enumerate(best_models, 1):  # 从 1 开始编号
        filename = os.path.join(save_dir, f"test_model_{i}.pt")
        torch.save(model.state_dict(), filename)  # 保存参数字典
        print(f"Saved {filename}")

# %%
save_best_models(top_model_weights, config.dataset, curr_task)
